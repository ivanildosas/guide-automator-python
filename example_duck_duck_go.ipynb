# %% [markdown]
# ## Access the website

# %%
from guide_automator_function import *

get("https://duckduckgo.com/")

takeScreenshot()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=937x900 at 0x7F7A74218D30>

# %% [markdown]
# ## Type what you want to know

# %%
highlight("#search_form_homepage")
fillIn("#search_form_input_homepage", 'Google stealing data')
pop("#logo_homepage_link", "I'm a duck", "left")
takeScreenshot()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=937x900 at 0x7F7A74146CC0>

# %% [markdown]
# ## Now, enjoy the internet!
#
# *Without having stolen data*

# %%
submit("#search_form_input_homepage")

takeScreenshot()

close()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=937x900 at 0x7F7A7413CA58>
