# %% [markdown]
# ## Access the website

# %%
from guide_automator_function import *

get("https://duckduckgo.com/")

takeScreenshot()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2386x1220 at 0x110F635C0>

# %% [markdown]
# ## Type what you want to know

# %%
highlight("#search_form_homepage")
fillIn("#search_form_input_homepage", 'Google stealing data')
pop("#logo_homepage_link", "I'm a duck", "left")
takeScreenshot()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2386x1220 at 0x111BE7F28>

# %% [markdown]
# ## Now, enjoy the internet!
#
# *Without having stolen data*

# %%
submit("#search_form_input_homepage")

takeScreenshot()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2386x1220 at 0x111BE7F60>
