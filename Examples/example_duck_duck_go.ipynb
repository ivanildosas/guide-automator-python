# %%
from guide_automator_function import *

get("https://www.google.com.br/")

highlight('#hplogo')

takeScreenshot()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=907x894 at 0x7F532C59AC88>
