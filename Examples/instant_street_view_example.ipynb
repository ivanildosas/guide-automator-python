# %% [markdown]
# ## Access the website.

# %%
from guide_automator_function import *

get("https://www.instantstreetview.com/")

takeScreenshot()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=907x894 at 0x7F8E81E6B898>

# %% [markdown]
# ## Type the place you want to go

# %%
highlight('#form')

takeScreenshot()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=907x894 at 0x7F8E81EADD30>

# %% [markdown]
# ## Now, enjoy!

# %%
fillIn('#search', 'Times Square')

takeScreenshot()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=907x894 at 0x7F8E81EADE80>
