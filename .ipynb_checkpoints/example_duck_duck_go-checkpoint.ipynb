# %%
from guide_automator_function import *

get("https://www.google.com.br/")

highlight('#hplogo')

takeScreenshot()

takeScreenshotOf('#hplogo')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=907x894 at 0x7FAD403419B0>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=907x894 at 0x7FAD40364F98>
