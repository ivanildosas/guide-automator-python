# %% [markdown]
# ## Access the website

# %%
from guide_automator_function import *

get("https://duckduckgo.com/")

takeScreenshot()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=907x894 at 0x7F3800A3B860>

# %% [markdown]
# ## Type what you want to know

# %%
highlight("#search_form_homepage")
fillIn("#search_form_input_homepage", 'Google stealing data')

takeScreenshot()

# %% [markdown]
# ## Now, enjoy the internet!
#
# *Without having stolen data*

# %%
submit("#search_form_input_homepage")

takeScreenshot()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=907x894 at 0x7F38009FED30>
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-3-0196a39c76c2> in <module>()
#       1 submit("#search_form_input_homepage")
#       2
# ----> 3 takeScreenshot()
#
# ~/Github/Py-GA/guide-automator-python/guide_automator_function.py in takeScreenshot()
#      34     sleep(3)
#      35     display(Image.open(io.BytesIO(wd.get_screenshot_as_png())))
# ---> 36     removeAllHighlights()
#      37
#      38 ## Take Screenshot of a specified element of the page and display it
#
# ~/Github/Py-GA/guide-automator-python/guide_automator_function.py in removeAllHighlights()
#      64     global listOfSelectors
#      65     for selector in listOfSelectors:
# ---> 66         removeHighlight(selector)
#      67     listOfSelectors = []
#      68 ## Make the program wait the time defined by parameter, on seconds
#
# ~/Github/Py-GA/guide-automator-python/guide_automator_function.py in removeHighlight(selector)
#      57 # Remove the highlight of a element, using the element CSS selector
#      58 def removeHighlight(selector):
# ---> 59     element = wd.find_element_by_css_selector(selector)
#      60     wd.execute_script('arguments[0].setAttribute("style", "outline: 0px solid red")', element)
#      61
#
# /usr/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in find_element_by_css_selector(self, css_selector)
#     595             element = driver.find_element_by_css_selector('#foo')
#     596         """
# --> 597         return self.find_element(by=By.CSS_SELECTOR, value=css_selector)
#     598
#     599     def find_elements_by_css_selector(self, css_selector):
#
# /usr/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in find_element(self, by, value)
#     964         return self.execute(Command.FIND_ELEMENT, {
#     965             'using': by,
# --> 966             'value': value})['value']
#     967
#     968     def find_elements(self, by=By.ID, value=None):
#
# /usr/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     318         response = self.command_executor.execute(driver_command, params)
#     319         if response:
# --> 320             self.error_handler.check_response(response)
#     321             response['value'] = self._unwrap_value(
#     322                 response.get('value', None))
#
# /usr/lib/python3.6/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"css selector","selector":"#search_form_homepage"}
#   (Session info: chrome=67.0.3396.99)
#   (Driver info: chromedriver=2.41.578700 (2f1ed5f9343c13f73144538f15c00b370eda6706),platform=Linux 4.14.54-1-MANJARO x86_64)
