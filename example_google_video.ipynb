# %% [markdown]
# ## Access the website

# %%
from guide_automator_function import *
from guide_automator_video import *

get("https://google.com/")
takeScreenshot()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1920x933 at 0x7F106A236A58>

# %% [markdown]
# ## Type what you want to know

# %%
speak("I love Jesus")
