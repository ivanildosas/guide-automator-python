# %% [markdown]
# ## Access the website

# %%
from guide_automator_function import *


get("https://google.com/")
takeScreenshot()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1920x933 at 0x7FD610100DA0>

# %% [markdown]
# ## Type what you want to know

# %%
clickOnElementWithCursor('div.gb_Q:nth-child(1)')
# Out:
# {'y': 19, 'x': 1637}
