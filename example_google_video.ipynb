# %% [markdown]
# ## Access the website

# %%
from guide_automator_function import *
from guide_automator_video import *

get("https://google.com/")
takeScreenshot()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1920x933 at 0x7F106AE5DBE0>

# %% [markdown]
# ## Type what you want to know

# %%
speak("I love Jesus")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-e5c496c13c9d> in <module>
# ----> 1 speak("I love Jesus")
#
# NameError: name 'speak' is not defined
